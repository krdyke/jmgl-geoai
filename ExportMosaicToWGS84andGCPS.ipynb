# %%
import arcgis
import os
from pprint import pprint

aerials_root_tdrive = r"T:\Maps\Maps_00\Aerial_Scanning_Project_00"
#aerial_dirs = [r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Major_1937\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Major_1966\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Marshall_1968\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Mayes_1938\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Mayes_1964\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Mayes_1972\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\McClain_1937\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\McCurtain_1967\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\McCurtain_1969\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\McIntosh_1967\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\McIntosh_1972\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Muskogee_1938\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Muskogee_1972\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Noble_1937\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Noble_1966\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Noble_1973\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Nowata_1958\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Nowata_1964\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Nowata_1972\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Okfuskee_1937\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Okfuskee_1968\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Oklahoma_1937\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Oklahoma_1963\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Oklahoma_1970\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Okmulgee_1938\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Okmulgee_1970\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Osage_1937\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Osage_1966\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Ottawa_1941\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Ottawa_1964\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Pawnee_1958\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Pawnee_1966\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Payne_1938\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Payne_1949\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Payne_1963\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Payne_1979\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Pittsburg_1967\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Pontotoc_1938\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Pontotoc_1940\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Pottawatomie_1937\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Pottawatomie_1961\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Rogers_1964\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Sequoyah_1964\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Sequoyah_1972\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Stephens_1937\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Stephens_1963\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Texas_1942\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Texas_1966\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Tillman_1971\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Tulsa_1938\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Tulsa_1943\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Tulsa_1958\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Tulsa_1964\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Washington_1937\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Washita_1937\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Washita_1966\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Woods_1937\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Woods_1965\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Woodward_1937\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Woodward_1965\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Woodward_1973\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Woodward_1981\_index"]
aerial_dirs = [r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Adair_1939\_index"]
redo_tif = False
 
if len(aerial_dirs) == 0:
    for i in os.scandir(aerials_root_tdrive):
        if i.is_dir() and not i.name.startswith("_"):
            #print(i.name)
            aerial_dirs.append(os.path.join(i.path, "_index"))
            
for i in aerial_dirs:
    arcpy.env.workspace = i
    county_name_and_year = i.split(os.path.sep)[4]
    print(county_name_and_year)
    tif_name = os.path.join(i, county_name_and_year + "_index_mosaic_wgs84.tif")
    print(tif_name)
    if arcpy.Exists(tif_name) and redo_tif == False:
        print("    tif exists, skip")
        continue

    index_jpgs = arcpy.ListRasters("*.jpg")
    if not index_jpgs:
        continue
    if len(index_jpgs) == 0:
        print("    no indexes found")
        continue
    index_jpgs = [os.path.join(i, a) for a in index_jpgs]
    #print(index_jpgs)
    index_gdb_dir = os.path.join(i, county_name_and_year + "_index.gdb")
    mosaic_name =  os.path.join(index_gdb_dir, county_name_and_year + "_index_mosaic")
    
    print("    Check for mosaic existence")
    if not arcpy.Exists(mosaic_name):
        print("        no mosaic found, skipping to next set")
        continue
    
    mosaic_curs = arcpy.da.SearchCursor(mosaic_name,"Category")
    rows = [row for row in mosaic_curs]
    if len(rows) == 0:
        print("      empty mosaic, skipping to next set")
        continue
    
    mosaic_desc = arcpy.da.Describe(mosaic_name)
    #pprint(mosaic_desc)
    #if mosaic_desc
    #print(mosaic_desc["childrenNames"])
    #print("AMD_" + county_name_and_year + "_index_mosaic_SML")
    seamline_name = "AMD_" + county_name_and_year + "_index_mosaic_SML"
    
    if seamline_name in mosaic_desc["childrenNames"]:
        print("    seamlines found")
    else:
        print ("    no seamlines found, try generating them")
        arcpy.management.BuildSeamlines(mosaic_name, update_existing="UPDATE_EXISTING")
        print("    seamlines built")
    
    print("    Default Mosaic Method: ", mosaic_desc["defaultMosaicMethod"])
    if not mosaic_desc["defaultMosaicMethod"] == "Seamline":
        
        print("        Set mosaic sort order to seamlines")
        arcpy.management.SetMosaicDatasetProperties(mosaic_name, geographic_transform="NAD_1983_To_WGS_1984_1", default_mosaic_method="Seamline")
        print("        done")
    else:
        print("    default mosaic method already seamline")
        
    
    tif_name = os.path.join(i, county_name_and_year + "_index_mosaic_wgs84.tif")

    in_coor = mosaic_desc["spatialReference"]
    
    # check for buffer, which should mean that the mosaic boundary is buffered appropriately
    buffer_name = os.path.join(i, county_name_and_year + "_buffer.shp")
    if not arcpy.Exists(buffer_name):
        print("    don't see a buffer")
        # Generate buffer ??
    
    #Project Raster to _index_mosaic_wgs84.tif
    if not arcpy.Exists(tif_name) or redo_tif:
        if redo_tif:
            print("    delete existing tif")
            arcpy.Delete_management(tif_name)
        print("    projecting raster...")
        arcpy.management.ProjectRaster(
            in_raster=mosaic_name,
            out_raster=tif_name,
            out_coor_system='GEOGCS["GCS_WGS_1984",DATUM["D_WGS_1984",SPHEROID["WGS_1984",6378137.0,298.257223563]],PRIMEM["Greenwich",0.0],UNIT["Degree",0.0174532925199433]]',
            resampling_type="NEAREST",
            geographic_transform=None,
            Registration_Point=None,
            in_coor_system=in_coor,
            vertical="NO_VERTICAL"
        )
        print("        done")
    else:
        print("    WGS84 tif already exists")

    
    
    # Extract by mask using buffer
# Out:
# Adair_1939
# T:\Maps\Maps_00\Aerial_Scanning_Project_00\Adair_1939\_index\Adair_1939_index_mosaic_wgs84.tif
#     tif exists, skip

# %%
proj = arcpy.mp.ArcGISProject("CURRENT")
map_view = proj.activeView
map1 = proj.activeMap

cty_lyr = map1.listLayers("ok_counties")[0]

arcpy.env.workspace = i
county_name_and_year = i.split(os.path.sep)[4]
county_name = county_name_and_year[:county_name_and_year.index("_")]
year = county_name_and_year[county_name_and_year.index("_")+1:]
q = "\"NAME\" = '{name}'".format(name=county_name.replace(" ",""))
cty_lyr.definitionQuery = q


buffer_name = county_name_and_year + "_buffer"
buffer = arcpy.analysis.PairwiseBuffer(cty_lyr, buffer_name, "2000 Meters")
print("        import buffer geom for boundary")

arcpy.management.ImportMosaicDatasetGeometry(
    mosaic_name, "BOUNDARY", "OBJECTID", buffer, "FID")

# %% [markdown]
# # Extract GCPs from Tiff and export to CSV

# %%
"""
Extract corner coordinates as "control points" using GDAL/Rasterio
"""


import rasterio
from rasterio import Affine
from rasterio.warp import reproject, Resampling, calculate_default_transform
from rasterio.transform import from_origin
from rasterio.warp import transform_bounds
from rasterio.control import GroundControlPoint

import json
import csv
import os
from pprint import pprint

aerials_root_tdrive = r"T:\Maps\Maps_00\Aerial_Scanning_Project_00"
#aerial_dirs = [r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Kay_1976\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Kingfisher_1964\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Kingfisher_1970\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Kiowa_1937\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Kiowa_1957\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Kiowa_1964\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Kiowa_1970\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Latimer_1967\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\LeFlore_1963\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\LeFlore_1967\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\LeFlore_1969\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Lincoln_1937\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Lincoln_1961\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Lincoln_1968\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Logan_1937\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Logan_1964\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Logan_1970\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Love_1963\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Love_1968\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Major_1937\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Major_1966\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Marshall_1968\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Mayes_1938\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Mayes_1964\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Mayes_1972\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\McClain_1937\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\McCurtain_1967\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\McCurtain_1969\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\McIntosh_1967\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\McIntosh_1972\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Muskogee_1938\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Muskogee_1972\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Noble_1937\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Noble_1966\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Noble_1973\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Nowata_1958\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Nowata_1964\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Nowata_1972\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Okfuskee_1937\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Okfuskee_1968\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Oklahoma_1937\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Oklahoma_1963\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Oklahoma_1970\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Okmulgee_1938\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Okmulgee_1970\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Osage_1937\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Osage_1966\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Ottawa_1941\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Ottawa_1964\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Pawnee_1958\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Pawnee_1966\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Payne_1938\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Payne_1949\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Payne_1963\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Payne_1979\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Pittsburg_1967\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Pontotoc_1938\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Pontotoc_1940\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Pottawatomie_1937\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Pottawatomie_1961\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Rogers_1964\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Sequoyah_1964\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Sequoyah_1972\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Stephens_1937\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Stephens_1963\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Texas_1942\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Texas_1966\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Tillman_1971\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Tulsa_1938\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Tulsa_1943\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Tulsa_1958\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Tulsa_1964\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Washington_1937\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Washita_1937\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Washita_1966\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Woods_1937\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Woods_1965\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Woodward_1937\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Woodward_1965\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Woodward_1973\_index",r"T:\Maps\Maps_00\Aerial_Scanning_Project_00\Woodward_1981\_index"]
aerial_dirs = []
#input_files = ["T:\Maps\Maps_00\Aerial_Scanning_Project_00\Beaver_1966\_index\Beaver_1966_index_mosaic_wgs84.tif"]
input_files = []

if len(aerial_dirs) == 0:
    for i in os.scandir(aerials_root_tdrive):
        if i.is_dir() and not i.name.startswith("_"):
            #print(i.name)
            aerial_dirs.append(os.path.join(i.path, "_index"))

            
for i in aerial_dirs:
    county_name_and_year = i.split(os.path.sep)[4]
    wgs84tif_fn = os.path.join(i, county_name_and_year+"_index_mosaic_wgs84.tif")
    if arcpy.Exists(wgs84tif_fn):
        input_files.append(wgs84tif_fn)
        

csv_file = open(os.path.join(aerials_root_tdrive,"output_GCPs.csv"), "w", newline="\n",encoding="utf8")
csv_writer = csv.DictWriter(csv_file,fieldnames={"external_id", "gcps"})

rows = []

print("starting:")

for input_file in input_files:
    
    print("  now on:", input_file)
    input_raster = rasterio.open(input_file)
    input_file_name = os.path.split(input_file)[-1]

    height = input_raster.height
    width = input_raster.width

    bounds = input_raster.bounds
    l1 = bounds.left 
    r1 = bounds.right
    t1 = bounds.top
    b1 = bounds.bottom

    bounds_wgs84 = transform_bounds(input_raster.crs, 
                    rasterio.CRS.from_epsg(4326), 
                    l1, b1, r1, t1, 
                    densify_pts=21)
    #pprint(bounds_wgs84)
    
    l = bounds_wgs84[0] 
    b = bounds_wgs84[1]
    r = bounds_wgs84[2]
    t = bounds_wgs84[3]
                            #row, col, x, y
    tl = GroundControlPoint(0, 0, t, l)
    bl = GroundControlPoint(height, 0, b, l)
    br = GroundControlPoint(height, width, b, r)
    tr = GroundControlPoint(0, width, t, r)

    gcps = [tl, bl, br, tr]
    gcps_dicts = []
    #pprint(gcps)
    for gcp in gcps:
        #print("[y,x]:",gcp.y,gcp.x)
        gcps_dicts.append({
            "pixel":[gcp.col,gcp.row],
            "location": [gcp.y,gcp.x ]               
            })

    #print(gcps_dicts)

    #this is happening on MK end, so don't need it here (yet....??)
    #gcp_str = ''
    #for gcp in gcps_dicts:
    #   lng, lat = gcp['location']
    #   x, y = gcp['pixel']
    #   gcp_str += '-gcp ' + str(x) + ' ' + str(y) + ' ' + str(lng) + ' ' + str(lat) + ' '
    
    #print(str(gcps_dicts))
    rows.append({
        "external_id":os.path.splitext(input_file_name)[0], 
        "gcps": str(gcps_dicts)
    })
    
csv_writer.writeheader()
csv_writer.writerows(rows)
csv_file.close()

# %%
# Out:
# Adair_1964_index_mosaic_wgs84.tif uploaded |██████████████████████████████| 100.0% complete (1/1 files)	[time elapsed: 0:00:04.181781]
